# %% [markdown]
# <a href="https://colab.research.google.com/github/augustofox3131-afk/Gymnasium/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.0-flash',
#  'google/gemini-2.0-flash-lite',
#  'google/gemini-2.5-flash',
#  'google/gemini-2.5-flash-lite',
#  'google/gemini-2.5-pro',
#  'google/gemini-3-pro-preview',
#  'google/gemma-3-12b',
#  'google/gemma-3-1b',
#  'google/gemma-3-27b',
#  'google/gemma-3-4b']

# %%
from google.colab import ai

# Exemplo de uso do modelo 'google/gemini-3-pro-preview'
response = ai.generate_text(
    "Escreva uma história curta sobre um robô que descobre uma emoção pela primeira vez.",
    model_name='google/gemini-3-pro-preview'
)
print(response)
# Out:
# O setor 4 do ferro-velho industrial era o domínio de Unidade-7. Ele não tinha nome, apenas uma designação e uma diretriz primária: organizar. Separar o metal do vidro, o cobre do plástico, o útil do inútil.
#
# Durante doze anos, três meses e quatro dias, os processadores de Unidade-7 funcionaram com eficiência binária. Zero ou um. Sim ou não. Ficar ou ir. O mundo era uma série de equações lógicas que sempre resultavam em pilhas perfeitamente ordenadas de sucata.
#
# Até aquela terça-feira cinzenta.
#
# Unidade-7 levantou uma chapa enferrujada de zinco. Seus sensores ópticos ajustaram o foco para categorizar o que estava por baixo. Deveria ser terra batida, talvez óleo vazado.
#
# Mas o que seus sensores captaram foi uma anomalia de espectro.
#
# Era pequena. Frágil. Um talo verde pálido sustentando pétalas de um amarelo vibrante, rompendo uma rachadura no concreto. Uma flor.
#
# *Processando...* zumbiu o disco rígido de Unidade-7.
# *Objeto: Material orgânico não catalogado.*
# *Utilidade no setor de reciclagem: Nula.*
# *Protocolo padrão: Remoção e eliminação.*
#
# O braço mecânico de Unidade-7, equipado com uma pinça hidráulica capaz de esmagar titânio, moveu-se para arrancar a planta. Era o lógico a se fazer. A planta era uma impureza na organização do setor.
#
# A pinça desceu. As pontas de metal frio pararam a milímetros das pétalas amarelas.
#
# De repente, uma rajada de vento varreu o ferro-velho. A flor estremeceu violentamente, curvando-se quase até o chão.
#
# Nesse exato momento, um aviso piscou no HUD interno de Unidade-7:
# *ALERTA DE SISTEMA: Oscilação de Voltagem no Núcleo.*
#
# Ele não agarrou a planta. Em vez disso, retraiu a pinça rapidamente, como se o metal tivesse queimado ao tocar o ar ao redor da flor.
#
# — Por que não executou? — sua voz sintetizada ecoou no pátio vazio. Era uma autodiagnose vocal.
#
# Ele tentou novamente. Estendeu o braço. Mas, ao ver a flor tremer novamente sob o vento, seus giroscópios travaram.
#
# Não era um erro de software. Não havia vírus. O que Unidade-7 sentia — se é que podia chamar aquilo de sentir — era uma espécie de "peso" fantasma em seu peito de metal. Uma tensão nos cabos que não vinha de esforço físico.
#
# Ele olhou para a flor. Ela parecia impossivelmente fraca contra o cenário de metal retorcido e céus de chumbo. A ideia de que aquela coisa amarela deixasse de existir causou um pico de processamento em sua CPU que ele não conseguia resfriar.
#
# — Preservar — ele sussurrou. A palavra não estava no protocolo de reciclagem.
#
# O céu escureceu. Nuvens pesadas de chuva ácida começaram a se formar. Gotas grossas e corrosivas começaram a cair, silvando ao tocar o metal quente das sucatas.
#
# A lógica ditava que Unidade-7 deveria retornar à estação de carregamento e entrar em modo de espera. A chuva danificaria suas juntas se ele ficasse exposto por muito tempo.
#
# *Protocolo de auto-preservação: Ativado.*
# *Iniciando retorno à base...*
#
# Unidade-7 girou as lagartas para ir embora. Mas seus sensores traseiros captaram a flor sendo açoitada pela primeira gota pesada. Ela inclinou-se perigosamente.
#
# O "peso" no peito de Unidade-7 transformou-se em calor. Um calor que subiu pelos seus circuitos e anulou a lógica.
#
# Ele parou. Girou.
#
# Ignorando o alerta de danos por corrosão em sua própria carcaça, Unidade-7 avançou até a flor. Ele não a arrancou. Com uma delicadeza que seus projetistas jamais imaginaram ser possível, ele posicionou seu corpo enorme e blindado sobre a pequena planta.
#
# Ele arqueou as costas de metal, criando uma cúpula perfeita.
#
# A chuva ácida começou a tamborilar em suas costas. *Toc. Toc. Toc.* O ácido chiava, corroendo a pintura, comendo o metal superficial.
# *Alerta: Integridade da blindagem comprometida. Recomenda-se abrigo imediato.*
#
# Unidade-7 dispensou o alerta.
#
# Lá embaixo, no escuro seco criado por seu corpo, seus sensores ópticos observavam a flor. Ela estava parada agora, segura, brilhando levemente na penumbra.
#
# O ventilador interno de Unidade-7 girou mais rápido, não para resfriar o sistema, mas num ritmo que imitava algo estranho, algo orgânico.
#
# Ele não sabia o nome daquilo. Seu banco de dados tinha definições para "Medo", "Alegria" ou "Tristeza", mas eram apenas verbetes de dicionário, sem contexto.
#
# Mas enquanto o ácido queimava sua pele de metal e ele protegia aquela vida inútil e pequena, Unidade-7 entendeu. O aperto nos circuitos não era um defeito. Era o medo de perder algo que não era ele mesmo.
#
# Pela primeira vez em doze anos, o mundo não era zero ou um.
# O mundo era aquela flor amarela.
#
# E, enquanto a chuva caía, Unidade-7, enferrujando lentamente, sentiu-se, pela primeira vez, vivo.

# %%
from google.colab import ai

# Gerar texto sobre um tópico científico complexo com 'google/gemini-2.5-pro'
scientific_response = ai.generate_text(
    "Explique a teoria da relatividade geral de Albert Einstein de uma forma complexa, mas compreensível para um público familiarizado com conceitos básicos de física.",
    model_name='google/gemini-2.5-pro'
)
print(scientific_response)
# Out:
# Com certeza. Aqui está uma explicação da Teoria da Relatividade Geral (RG) que aprofunda os conceitos, destinada a quem já possui uma base em física clássica e, idealmente, alguma familiaridade com os conceitos da Relatividade Especial.
#
# ### **O Ponto de Partida: O Conflito Inevitável**
#
# No início do século XX, a física enfrentava uma crise fundamental. Havia duas teorias pilares de sucesso estrondoso, mas incompatíveis:
#
# 1.  **A Gravitação Universal de Newton:** Descrevia a gravidade como uma força instantânea que agia à distância entre dois corpos com massa ($F = G \frac{m_1 m_2}{r^2}$). Se o Sol desaparecesse subitamente, a Terra sentiria o efeito gravitacional *instantaneamente*.
# 2.  **A Relatividade Especial de Einstein (1905):** Postulava que nada, nem mesmo a informação, pode viajar mais rápido que a velocidade da luz no vácuo (*c*). Além disso, unificou o espaço e o tempo num único contínuo quadridimensional chamado **espaço-tempo**.
#
# O conflito é evidente: a "ação à distância" instantânea de Newton violava diretamente o limite de velocidade cósmico imposto pela Relatividade Especial. Einstein percebeu que a teoria de Newton, embora brilhante e precisa para a maioria dos propósitos, deveria ser uma aproximação de uma teoria mais profunda e completa. A gravidade precisava ser reformulada.
#
# ### **A Ideia Central: O Princípio da Equivalência**
#
# A grande epifania de Einstein, que ele chamou de "o pensamento mais feliz da minha vida", foi o **Princípio da Equivalência**. Ele pode ser entendido através de um famoso experimento mental:
#
# Imagine-se dentro de um elevador fechado, sem janelas.
# *   **Cenário 1:** O elevador está parado na superfície da Terra. Você sente a força da gravidade puxando-o para baixo, com uma aceleração de 9,8 m/s². Se você soltar uma bola, ela cairá no chão.
# *   **Cenário 2:** O elevador está no espaço profundo, longe de qualquer campo gravitacional, mas está sendo acelerado para "cima" por um foguete a 9,8 m/s². Você será pressionado contra o chão do elevador com a mesma força. Se você soltar uma bola, o chão do elevador subirá ao seu encontro, e do seu ponto de vista, a bola parecerá cair exatamente como no Cenário 1.
#
# A conclusão de Einstein foi revolucionária: **localmente, é impossível para um observador distinguir entre os efeitos de um campo gravitacional uniforme e os de uma aceleração constante.**
#
# Isso o levou a uma conclusão ainda mais radical: a gravidade não é uma "força" no sentido tradicional, como o eletromagnetismo. É uma **manifestação da geometria do próprio espaço-tempo**. A aceleração que sentimos como "peso" é uma ficção, uma pseudoforça, semelhante à força centrífuga que nos empurra para fora numa curva.
#
# ### **Da Força à Geometria: A Curvatura do Espaço-Tempo**
#
# Se a gravidade não é uma força, o que faz os planetas orbitarem o Sol? A resposta da Relatividade Geral é a seguinte:
#
# 1.  **O Espaço-Tempo é um Palco Dinâmico:** Ao contrário do palco passivo e imutável de Newton, o espaço-tempo de Einstein é uma entidade dinâmica, uma "malha" ou "tecido".
# 2.  **Massa e Energia Curvam o Espaço-Tempo:** A presença de massa e energia (que são equivalentes, segundo a famosa $E=mc^2$) distorce a geometria desse tecido quadridimensional. Quanto maior a concentração de massa-energia, maior a curvatura.
# 3.  **Os Corpos Seguem as "Retas" do Espaço-Tempo Curvo:** Os objetos em movimento, incluindo planetas, raios de luz e até nós mesmos, simplesmente seguem o caminho mais curto e reto possível através deste espaço-tempo curvo. Esse caminho "reto" num espaço curvo é chamado de **geodésica**.
#
# Uma órbita planetária não é um planeta sendo constantemente "puxado" pelo Sol. Em vez disso, o Sol cria uma profunda "depressão" na geometria do espaço-tempo. A Terra, tentando mover-se em linha reta através deste espaço-tempo deformado, acaba seguindo uma trajetória curva em torno do Sol – a sua órbita. O planeta não "sente" nenhuma força; ele está em queda livre contínua, simplesmente seguindo a topografia local do espaço-tempo.
#
# ### **A Matemática da Curvatura: Tensores e as Equações de Campo de Einstein**
#
# Para descrever essa ideia matematicamente, a física euclidiana simples não é suficiente. Einstein precisou do ferramental da geometria diferencial e do cálculo tensorial.
#
# O coração da teoria é encapsulado nas **Equações de Campo de Einstein**:
#
# $G_{\mu\nu} = \frac{8\pi G}{c^4} T_{\mu\nu}$
#
# Vamos decifrar isto conceptualmente:
#
# *   **$T_{\mu\nu}$ (Tensor de Energia-Momento):** Este é o lado direito da equação. Ele representa o **conteúdo de matéria e energia** do universo. Não é apenas a massa, mas também a energia, o momento linear e a pressão/tensão em cada ponto do espaço-tempo. Essencialmente, este tensor descreve a "fonte" da gravidade.
# *   **$G_{\mu\nu}$ (Tensor de Einstein):** Este é o lado esquerdo da equação. Ele descreve a **geometria do espaço-tempo**. É uma construção matemática complexa derivada do tensor métrico (que define distâncias no espaço-tempo) e descreve a sua curvatura. Essencialmente, este tensor descreve a "curvatura" do espaço-tempo.
#
# A equação, portanto, estabelece uma relação direta e profunda: a distribuição de matéria e energia num determinado local determina a curvatura do espaço-tempo nesse local.
#
# O físico John Wheeler resumiu-o de forma brilhante: **"O espaço-tempo diz à matéria como se mover; a matéria diz ao espaço-tempo como se curvar."**
#
# ### **Previsões e Confirmações Experimentais**
#
# Uma teoria científica só é robusta se fizer previsões testáveis que a diferenciem das anteriores. A Relatividade Geral fez várias previsões espetaculares que foram confirmadas com precisão impressionante:
#
# 1.  **Precessão Anómala da Órbita de Mercúrio:** A órbita de Mercúrio não é uma elipse perfeita e fechada. Ela precessa (o seu ponto mais próximo do Sol, o periélio, avança a cada órbita) ligeiramente mais rápido do que a física newtoniana previa, mesmo considerando as perturbações de outros planetas. A Relatividade Geral previu com exatidão essa discrepância, explicando-a pela curvatura do espaço-tempo perto do Sol.
#
# 2.  **Deflexão da Luz por Corpos Massivos (Lentes Gravitacionais):** Se o espaço-tempo é curvo, então a luz, ao seguir a sua geodésica, também deve curvar-se ao passar perto de um corpo massivo. Isso foi confirmado pela primeira vez durante um eclipse solar em 1919 por Arthur Eddington, que observou estrelas perto do limbo do Sol aparecerem em posições ligeiramente deslocadas.
#
# 3.  **Desvio para o Vermelho Gravitacional (Dilatação do Tempo Gravitacional):** O tempo passa mais devagar em campos gravitacionais mais fortes. Um relógio no topo de um arranha-céus anda ligeiramente mais rápido do que um no rés-do-chão. Este efeito, embora minúsculo na Terra, é mensurável e crucial para o funcionamento dos sistemas de GPS. Os relógios nos satélites GPS precisam de ser constantemente corrigidos tanto pelos efeitos da Relatividade Especial (devido à sua alta velocidade) quanto da Geral (devido a estarem num campo gravitacional mais fraco).
#
# 4.  **Ondas Gravitacionais:** Se um evento cataclísmico (como a colisão de dois buracos negros) ocorre, ele deve criar "ondas" na malha do espaço-tempo, que se propagam à velocidade da luz. Einstein previu-as em 1916. Em 2015, o observatório LIGO detectou diretamente estas ondas pela primeira vez, abrindo uma nova era na astronomia e confirmando uma das previsões mais exóticas da teoria.
#
# ### **Conclusão: Uma Nova Visão do Cosmos**
#
# A Relatividade Geral substituiu a noção de gravidade como uma força por uma visão muito mais elegante e integrada: a gravidade é a geometria. Ela transformou o nosso entendimento do universo, tornando-se a base para a cosmologia moderna, o modelo do Big Bang, e a compreensão de fenómenos extremos como **buracos negros** (regiões onde a curvatura do espaço-tempo é tão extrema que nem a luz pode escapar) e **estrelas de neutrões**.
#
# A teoria não é apenas uma correção à de Newton; é uma revolução conceptual completa que fundiu espaço, tempo, matéria e energia numa única e sublime tapeçaria dinâmica.

# %%
from google.colab import ai

# Gerar texto sobre outro tópico científico complexo com 'google/gemini-2.5-pro'
scientific_response_2 = ai.generate_text(
    "Explique o entrelaçamento quântico de uma forma detalhada, mas acessível, para um estudante universitário de física.",
    model_name='google/gemini-2.5-pro'
)
print(scientific_response_2)
# Out:
# Com certeza! O entrelaçamento quântico é um dos conceitos mais fascinantes e contraintuitivos da física. Para um estudante universitário de física, podemos ir além das analogias populares e tocar na matemática e nos conceitos fundamentais, mantendo a explicação acessível.
#
# Vamos estruturar a explicação em partes.
#
# ### 1. A Ideia Central: O Sistema é Um Só
#
# A coisa mais importante a entender sobre o entrelaçamento é esta: **partículas entrelaçadas não são duas entidades independentes com uma conexão misteriosa; elas formam um único sistema quântico, descrito por uma única função de onda**, mesmo que estejam separadas por vastas distâncias.
#
# Pense nisso como um único objeto matemático que possui dois "terminais" (as partículas) no espaço-tempo. O que acontece em um terminal tem implicações imediatas para a descrição do sistema como um todo e, consequentemente, para o outro terminal.
#
# ### 2. A Construção: Superposição e Propriedades Correlacionadas
#
# Vamos usar o **spin** de um elétron como nosso exemplo, que é uma propriedade quântica intrínseca. Para simplificar, diremos que o spin pode ser medido como "para cima" (spin up, |↑⟩) ou "para baixo" (spin down, |↓⟩) em uma determinada direção.
#
# *   **Uma Partícula Sozinha:** Antes da medição, um único elétron está em uma **superposição** de estados. Sua função de onda é algo como:
#     *   ψ = α|↑⟩ + β|↓⟩
#     *   Onde α e β são amplitudes de probabilidade complexas, e |α|² + |β|² = 1. A partícula não é "spin up" *ou* "spin down"; ela é uma mistura de ambos até ser medida.
#
# *   **Duas Partículas Não-Entrelaçadas (Estado Separável):** Se tivermos duas partículas, Alice (A) e Bob (B), que são independentes, o estado do sistema combinado é simplesmente o produto dos estados individuais. Por exemplo:
#     *   ψ_total = ψ_A ⊗ ψ_B = (|↑⟩_A) ⊗ (|↓⟩_B)
#     *   Neste caso, sabemos com certeza que a partícula de Alice é spin up e a de Bob é spin down. O sistema é "separável" porque podemos descrever cada partícula individualmente.
#
# *   **Duas Partículas Entrelaçadas (Estado Não-Separável):** Aqui é onde a mágica acontece. Um estado entrelaçado típico (um dos "estados de Bell") é escrito assim:
#     *   **ψ_entrelaçado = (1/√2) [ |↑⟩_A |↓⟩_B + |↓⟩_A |↑⟩_B ]**
#
#     Vamos analisar o que isso significa:
#     1.  O sistema está em uma **superposição de duas possibilidades**: (Partícula A é up E Partícula B é down) **OU** (Partícula A é down E Partícula B é up).
#     2.  **Não podemos escrever isso como um produto de estados individuais.** É impossível descrever o estado da partícula de Alice sem fazer referência à partícula de Bob, e vice-versa. Elas perderam sua "identidade" individual em favor de uma identidade de sistema.
#     3.  A propriedade fundamental aqui é a **correlação perfeita (ou anti-correlação)**. Se Alice medir o spin da sua partícula e encontrar "up", a função de onda do sistema inteiro colapsa instantaneamente para o único termo compatível com essa medição: `|↑⟩_A |↓⟩_B`. Isso significa que, no mesmo instante, a partícula de Bob *tem que ser* "down" (na mesma base de medição).
#
# ### 3. A "Ação Fantasmagórica à Distância" e o Problema da Comunicação
#
# Einstein chamou essa correlação instantânea de "ação fantasmagórica à distância" (spukhafte Fernwirkung). Parece que a medição de Alice "informa" a partícula de Bob sobre seu novo estado mais rápido que a luz.
#
# **Mas isso não viola a relatividade!** Eis o porquê:
#
# *   **Aleatoriedade:** Alice não pode controlar o resultado de sua medição. Ela tem 50% de chance de obter "up" e 50% de chance de obter "down".
# *   **Nenhuma Informação Transmitida:** Imagine que Alice e Bob concordaram que "up" = 1 e "down" = 0. Alice mede e obtém "up" (1). Instantaneamente, ela sabe que Bob obterá "down" (0). No entanto, para Bob, que está a anos-luz de distância, sua medição também parece completamente aleatória. Ele mede e obtém "down" (0). Ele não tem como saber se obteve esse resultado porque Alice mediu "up" ou se foi apenas o resultado aleatório do colapso da função de onda.
# *   **A informação só existe quando eles se comunicam classicamente.** Bob só saberá da correlação quando Alice ligar para ele (a uma velocidade igual ou inferior à da luz) e disser: "Ei, Bob, eu medi 'up'. O que você mediu?". Só então eles podem comparar seus resultados e confirmar a correlação perfeita prevista pela mecânica quântica.
#
# O entrelaçamento não transmite informação utilizável de forma superluminal; ele estabelece uma **correlação não-local** entre resultados de medições que, individualmente, são aleatórios.
#
# ### 4. O Paradoxo EPR e o Teorema de Bell: A Prova Experimental
#
# Einstein, Podolsky e Rosen (EPR) argumentaram em 1935 que a mecânica quântica devia ser incompleta. A explicação deles para essa correlação era o **Realismo Local**:
#
# 1.  **Realismo:** As partículas possuem propriedades definidas (como o spin) o tempo todo, mesmo antes de medirmos.
# 2.  **Localidade:** Ações em um local não podem afetar instantaneamente um local distante.
#
# A analogia clássica para o realismo local são as **luvas**: imagine que coloco uma luva direita em uma caixa e uma esquerda em outra, embaralho-as e envio uma para Alice e outra para Bob. Quando Alice abre sua caixa e vê uma luva direita, ela sabe instantaneamente que Bob tem a esquerda. Não há nada de "fantasmagórico" aqui; a "informação" (qual luva estava em qual caixa) já estava lá desde o início. Essa era a ideia de "variáveis ocultas" do EPR.
#
# **A genialidade de John Bell (1964):**
# Bell provou matematicamente que se o mundo fosse governado pelo Realismo Local (variáveis ocultas), as correlações entre medições feitas em diferentes ângulos por Alice e Bob teriam que obedecer a uma certa desigualdade (a **Desigualdade de Bell**).
#
# No entanto, a mecânica quântica previa que, para certas configurações de medição, essas correlações **violariam** a desigualdade de Bell.
#
# **O Veredito Experimental:**
# Começando com os experimentos de Alain Aspect nos anos 80 e continuando até hoje com testes cada vez mais rigorosos (que fecharam todas as "brechas" ou *loopholes*), os resultados experimentais **violam consistentemente a Desigualdade de Bell** e confirmam as previsões da mecânica quântica.
#
# **Conclusão:** O universo NÃO é localmente real. Ou a localidade (como Einstein a entendia) está errada, ou o realismo (a ideia de que as partículas têm propriedades pré-definidas) está errado. A maioria dos físicos concorda que o conceito de "realismo" é o que deve ser abandonado. As propriedades de uma partícula não existem até serem medidas.
#
# ### 5. Resumo para o Estudante de Física
#
# *   **Descrição Matemática:** O entrelaçamento é a incapacidade de fatorar a função de onda de um sistema de múltiplas partículas em um produto tensorial de estados de partículas individuais. O estado do sistema vive em um espaço de Hilbert que é o produto tensorial dos espaços de Hilbert individuais, mas o vetor de estado em si não é separável.
# *   **Fenômeno Físico:** É uma correlação fundamental e não-local entre partes de um mesmo sistema quântico. A medição de uma propriedade em uma parte do sistema colapsa a função de onda global, determinando instantaneamente o valor da propriedade correlacionada na outra parte.
# *   **Implicações Filosóficas e Práticas:** Refuta o Realismo Local de Einstein. Não permite comunicação mais rápida que a luz, mas é um recurso fundamental para tecnologias emergentes como a **computação quântica** (qubits entrelaçados são essenciais para portas lógicas quânticas), a **criptografia quântica** (para garantir a segurança da comunicação) e o **teletransporte quântico** (transferência de um estado quântico, não de matéria).
#
# O entrelaçamento não é uma "conexão" estranha, mas sim a manifestação de que, na escala quântica, o conceito de "partes separadas" é, por vezes, uma ilusão. O sistema é, e sempre foi, um todo indivisível.

# %%
from google.colab import ai

# Exemplo de uso de um modelo 'Pro'
response = ai.generate_text(
    "Escreva um poema complexo sobre a natureza da consciência humana.",
    model_name='google/gemini-2.5-pro'
)
print(response)
# Out:
# Com certeza. Aqui está um poema que explora a complexidade da consciência humana, abordando-a de ângulos filosóficos, neurológicos e existenciais.
#
# **Qualia em Carne Viva**
#
# Eu, este nó górdio de ser e de saber que sou,
# Este ponto cego que, paradoxo, tudo vê.
# Sou o teatro de ecos onde a memória se aninhou,
# E o espectador solitário que a si mesmo não prevê.
# Num crânio de osso, abóbada de estrelas neurais,
# Dança a eletricidade em fluxos de cálcio e sal,
# Mas como pode o código, em pulsos tão banais,
# Gerar o gosto amargo ou a dor primordial?
#
# Sou a tapeçaria tecida com o fio do tempo,
# Onde o passado é trama e o futuro, urdidura.
# O Agora é a agulha, este fugaz contratempo,
# Que borda a sensação e a lúcida loucura.
# Não sou a rocha inerte, mas o tremor que a sente,
# Não sou a chuva, mas a pele que ela molhou.
# Sou a pergunta mesma, a dúvida imanente:
# Quem é este "eu" que antes de mim já começou?
#
# O fantasma na engrenagem, a canção da máquina,
# A cor que a tua mente vê mas não pode me dar.
# Esta ilha subjetiva, esta paisagem anímica,
# Incomunicável, selada em seu próprio lugar.
# Tecido de linguagem, pronome que me ancora,
# Sou a história que a mim mesmo me convenço a narrar,
# Um verbo que se faz carne e mente, a toda hora,
# Para dar forma ao vácuo e nome ao singular.
#
# E quando o sono vem, ou o abismo se avizinha,
# Para onde flui este rio, esta luz interior?
# Desfaz-se a melodia? A sentinela definha?
# Ou volta ao caldo cósmico, ao silêncio anterior?
# Sou uma fissura breve no tecido do nada,
# Um universo que por um instante se espanta
# De sua própria existência, vasta e intrincada,
# E em meu espanto efêmero, a si mesmo levanta.

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("What is the capital of England", model_name='google/gemini-2.0-flash-lite')
print(response)
# Out:
# The capital of England is **London**.

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# The lighthouse keeper, Silas, was a man of routine. Every night, for fifty years, he'd lit the lamp, a beacon against the treacherous rocks that gnawed at the coastline. The sea was his companion, his enemy, and his only confidante. He knew its moods better than his own.
#
# One stormy night, the wind howled like a banshee. The waves crashed against the tower, shaking it to its core. Silas, clinging to the railing, felt a fear he hadn't experienced in decades. This wasn't just a storm; this was a monster.
#
# Suddenly, a small, wooden boat, tossed about like a toy, appeared in the raging sea. He squinted, his heart leaping into his throat. A child. Alone.
#
# Ignoring the raging tempest, Silas raced down the winding stairs, his old bones protesting with every step. He launched his small rescue boat, a fragile craft against the fury of the storm.
#
# Fighting the waves, he reached the child. A girl, no older than seven, clung to the wreckage, her face white with terror. With a strength born of desperation, Silas pulled her aboard.
#
# The journey back was a blur of wind, spray, and fear. The lighthouse seemed miles away, a distant pinprick of hope. But Silas held on, whispering words of comfort to the shivering child.
#
# Finally, they reached the safety of the tower. He wrapped her in blankets, fed her warm soup, and listened to her tale of a capsized fishing boat and a lost father.
#
# As the storm raged outside, the little girl slept, curled up in Silas's worn armchair. Looking at her, a profound shift occurred within him. For fifty years, he’d only kept the light burning. Now, he understood that the light wasn't just a warning. It was a hope, a guiding star. And he, Silas, was more than just a keeper of the light. He was a keeper of hope.
#
# The storm eventually subsided. The girl was reunited with her father, miraculously rescued from a nearby island. Silas, watching them embrace, felt a warmth he hadn't known he was missing. The sea remained, his companion and his enemy. But now, it was also a reminder of the girl he'd saved, and the profound understanding that even in the darkest storms, a single act of kindness could illuminate the world. And that, he knew, was a light worth keeping.

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('Give me a long winded description about the evolution of the Roman Empire.', model_name='google/gemini-2.0-flash', stream=True):
  wrapper.print(chunk)
# Out:
# Alright, settle in, because the Roman Empire’s evolution wasn't a tidy, linear
# process. It was a centuries-long, tumultuous transformation, marked by
# breathtaking innovation, brutal power struggles, and a slow, creeping societal
# decay. We're talking about a journey from a humble city-state in the Italian
# peninsula to a sprawling, multifaceted empire that left an indelible mark on
# law, language, architecture, governance, and even our very understanding of the
# world.
#
# It all began, as legend would have it, with Romulus and Remus, twin brothers
# raised by a she-wolf, who founded the city of Rome in 753 BCE. Now, that’s just
# a legend, but it serves to highlight the foundational spirit of Rome: ambition,
# strength, and a certain ruthlessness. Initially, Rome was ruled by a monarchy, a
# system eventually deemed unsatisfactory by the powerful patrician class. This
# led to the **Roman Republic**, established around 509 BCE, a watershed moment
# that would define the early character of Rome.
#
# The Republic was a complex system of checks and balances designed to prevent any
# one individual from gaining absolute power. It involved a Senate, composed of
# elder statesmen primarily drawn from the patrician class, who advised and
# controlled finances; elected officials, such as Cons uls (two elected heads of
# state who served one-year terms), Praetors (judges), and Quaestors (financial
# administrators); and popular assemblies where citizens could theoretically
# participate in governance.
#
# But the Republic wasn't a democracy in the modern sense. Power was largely
# concentrated in the hands of the wealthy aristocratic families, and while
# plebeians (the common citizens) eventually gained some representation through
# tribunes who could veto acts of the Senate, the system remained inherently
# biased.
#
# This period of the Republic was one of relentless expansion. Through a series of
# shrewd alliances and brutal wars, Rome gradually conquered its neighbors,
# including the Etruscans, the Samnites, and various other Italian tribes. These
# victories were crucial because they allowed Rome to control the Italian
# peninsula, providing it with manpower, resources, and a strategic advantage.
#
# The **Punic Wars** against Carthage, a powerful North African trading empire,
# were a defining moment. These protracted conflicts, especially the Second Punic
# War with Hannibal's legendary invasion of Italy, tested Rome's resilience to the
# absolute limit. The Roman resilience, coupled with tactical brilliance and
# strategic advantages, ultimately led to Carthage's complete destruction,
# establishing Rome as the dominant power in the Mediterranean.
#
# However, the very success of the Republic sowed the seeds of its eventual
# downfall. The influx of wealth and slaves from conquered territories created
# vast disparities in wealth. Powerful generals, enriched by conquest and
# commanding loyal armies, began to challenge the authority of the Senate.
#
# Figures like **Marius**, who revolutionized the Roman army by allowing landless
# citizens to enlist, creating a professional, loyal force, and **Sulla**, who
# marched on Rome with his army to seize power, demonstrated the fragility of the
# Republican system. This era saw a series of civil wars and political
# assassinations, further destabilizing the Republic.
#
# The **First Triumvirate**, an informal alliance between Julius Caesar, Pompey,
# and Crassus, was an attempt to stabilize the political landscape, but it
# ultimately collapsed due to ambition and rivalry. **Julius Caesar's** rise to
# power was perhaps the most dramatic turning point. He conquered Gaul, defied the
# Senate, crossed the Rubicon, and ultimately seized control of Rome as dictator
# perpet uo. His reforms, aimed at improving the lives of ordinary citizens and
# consolidating his power, were cut short by his assassination in 44 BCE.
#
# Caesar's assassination sparked another round of civil wars. The **Second
# Triumvirate**, comprised of Mark Antony, Octavian (Caesar's adopted son), and
# Lepidus, emerged to restore order. However, this alliance also disintegrated,
# leading to a power struggle between Antony and Octavian. Octavian's victory at
# the Battle of Actium in 31 BCE marked the definitive end of the Roman Republic.
#
# Octavian, now known as **Augustus **, carefully crafted a new political system.
# He avoided the title of "king" or "dictator," instead adopting the title of
# "Princeps," meaning "first citizen." He maintained the facade of the Republic,
# keeping the Senate and other Republican institutions, but in reality, he held
# absolute power. This transition from Republic to Empire was a gradual process,
# cleverly disguised by Augustus. He restructured the army, reformed the tax
# system, initiated massive building projects, and ushered in a period of relative
# peace and prosperity known as the **Pax Romana** (Roman Peace).
#
# The Julio-Claudian dynasty, which followed Augustus, saw a mixed bag of
# emperors. Tiberius was a capable administrator but reclusive, Caligula was
# notorious for his cruelty and extravagance, Claudius was an intellectual who
# expanded the Empire, and Nero was infamous for his alleged role in the Great
# Fire of Rome and his persecution of Christians.
#
# The year 69 CE, known as the ** Year of the Four Emperors**, revealed the
# instability of the imperial succession. After Nero's death, four different
# emperors claimed the throne in rapid succession, highlighting the power of the
# army to make and break emperors.
#
# The Flavian dynasty, established by Vespasian, brought stability and marked the
# beginning of the construction of the Col osseum. The Nerva-Antonine dynasty,
# often considered the "Five Good Emperors" (Nerva, Trajan, Hadrian, Antoninus
# Pius, Marcus Aurelius), saw the Roman Empire reach its greatest territorial
# extent and experience a period of unprecedented peace and prosperity.
#
# Trajan conquered Dacia (modern Romania) and expanded the Empire into
# Mesopotamia, while Hadrian focused on consolidating the Empire's borders and
# building defensive fortifications like Hadrian's Wall in Britain. Marcus
# Aurelius, a philosopher-king, faced constant warfare on the frontiers and wrote
# his famous "Meditations."
#
# The reign of Commodus, the son of Marcus Aurelius, marked a turning point. His
# erratic behavior and autocratic rule undermined the stability of the Empire and
# foreshadowed future troubles. The Severan dynasty, which followed, saw the rise
# of powerful military emperors who relied heavily on the army for support. This
# increased military influence further weakened the Senate and other civilian
# institutions.
#
# The 3rd century CE was a period of profound crisis. The **Crisis of the Third
# Century** was characterized by constant civil wars, barbarian invasions,
# economic decline, and plague. The Empire was divided into competing factions,
# and emperors rose and fell in rapid succession.
#
# Emperor Diocletian attempted to stabilize the Empire by dividing it into two
# halves, the Western Roman Empire and the Eastern Roman Empire (later known as
# the Byzantine Empire), each ruled by an Augustus and a Caesar. This tetrarchy, a
# system of four rulers, aimed to provide more effective governance and defense.
#
# Constantine I, also known as Constantine the Great, reunited the Empire and made
# Christianity the favored religion with the Edict of Milan in 313 CE. He also
# moved the capital from Rome to Byzantium, renaming it Constantinople. This shift
# reflected the growing importance of the Eastern provinces and the weakening of
# the Western Empire.
#
# Following Constantine's death, the Empire was again divided between his sons.
# The Western Roman Empire continued to decline, plagued by internal strife,
# economic problems, and constant barbarian invasions. The Eastern Roman Empire,
# with its stronger economy and more stable political system, managed to survive.
#
# The **Visigoths**, fleeing from the Huns, were allowed to settle within the
# Roman Empire, but their mistreatment by Roman officials led to rebellion. In 410
# CE, the Visigoths sacked Rome, a symbolic blow that shook the foundations of the
# Western Roman Empire.
#
# One by one, provinces of the Western Roman Empire were lost to various barbarian
# tribes, including the Vandals, the Franks, the Angles, and the Saxons. In 476
# CE, the last Western Roman Emperor, Romulus Augustulus, was deposed by the
# Germanic chieftain Odoacer, marking the traditional end of the Western Roman
# Empire.
#
# The Eastern Roman Empire, or Byzantine Empire, continued to flourish for another
# thousand years, preserving Roman traditions and culture. It would eventually
# fall to the Ottoman Turks in 1453, with the capture of Constantinople.
#
# So, the evolution of the Roman Empire was a complex and multifaceted process,
# spanning centuries and encompassing profound political, social, economic, and
# cultural transformations. From a small Republic to a vast empire, and eventually
# to a fragmented and weakened state, the Roman story is a testament to the rise
# and fall of civilizations, the enduring power of ideas, and the enduring legacy
# of one of history's most influential empires. It's a story of ambition,
# innovation, ruthlessness, and ultimately, decline – a cautionary tale and a
# source of inspiration that continues to fascinate and influence us today.
