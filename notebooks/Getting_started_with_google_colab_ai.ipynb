# %% [markdown]
# <a href="https://colab.research.google.com/github/augustofox3131-afk/Gymnasium/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.0-flash',
#  'google/gemini-2.0-flash-lite',
#  'google/gemini-2.5-flash',
#  'google/gemini-2.5-flash-lite',
#  'google/gemini-2.5-pro',
#  'google/gemma-3-12b',
#  'google/gemma-3-1b',
#  'google/gemma-3-27b',
#  'google/gemma-3-4b']

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %%
from google.colab import ai

response = ai.generate_text("Write a short, creative story about a sentient teapot.", model_name='google/gemini-2.5-flash')
print(response)
# Out:
# Thelonious, a stout, cobalt-blue ceramic teapot, considered himself a connoisseur of quiet mornings. A mind, surprisingly nimble for a vessel of fired clay, hummed within his glazed shell, observing the world from his perch on the kitchen counter. He had no eyes, but perceived the shifting light, the warmth of the sun, and the looming shadow of Eleanor as she approached. He had no ears, but vibrations carried the murmur of her radio, the clatter of her mug, and the gentle sigh that always accompanied her first cuppa.
#
# His life was a cycle of anticipation, purpose, and reflection. He anticipated the gush of cold water, the soft clink of tea leaves settling in his belly, the invigorating heat of the stove, and the culminating, perfect brew. His purpose was singular: to transform water and leaf into comfort. His reflection was on the subtle alchemy, the steam blossoming from his spout like a tiny, ephemeral cloud, carrying the essence of camellia sinensis.
#
# Eleanor, his human, was unaware of the sophisticated internal monologue that accompanied her daily ritual. She saw a teapot; Thelonious saw a muse, a reason for being. He knew her moods by the strength of her brew: a light Earl Grey for thoughtful mornings, a robust Darjeeling for a determined day, a soothing chamomile when her shoulders were slumped. He *felt* the difference in the way she held him – firm and businesslike, or cradled gently, seeking solace.
#
# One blustery Tuesday, Eleanor was particularly quiet. The wind howled outside, mirroring a storm in her own heart, Thelonious suspected. She filled him with water, a bit distractedly, and chose a rare, delicate white tea – one reserved for introspection. As the water simmered, Thelonious focused his entire being on the infusion, guiding the warmth, coaxing the subtle floral notes from the leaves. He wanted to give her more than just tea; he wanted to give her peace.
#
# When she poured the pale golden liquid, Eleanor lingered, her fingers tracing the curve of his handle. "Thank you, old friend," she murmured, her voice barely a whisper. "You always know just what I need." She took a deep, fortifying breath, the steam warming her face.
#
# A quiet, incandescent joy bloomed within Thelonious. He was more than a vessel; he was a silent confidante, a purveyor of peace, a quiet heart in a bustling kitchen. He watched as Eleanor sipped her tea, a faint, contented smile beginning to soften her features. And in that moment, the sentient teapot knew his quiet, purposeful life was the most magnificent adventure of all.

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# Elara loved the late afternoon light best. It painted the city park in hues of soft gold and long shadows, making the everyday seem a little more magical. She sat on her usual bench, watching children chase pigeons and young lovers whisper secrets, a contented smile playing on her lips.
#
# Then, her hand went to her lapel, and the smile faltered. The silver hummingbird pin, a gift from her late husband, was gone. Her heart gave a little lurch. She’d worn it every day for twenty years.
#
# Frantically, she patted her pockets, ran her hands over the worn fabric of her skirt, and peered under the bench. Nothing. A knot of sadness tightened in her chest. It wasn't just a piece of jewelry; it was a tiny, shimmering anchor to her past.
#
# Just as a sigh of defeat escaped her, a small, red ball bounced erratically towards her bench. A young boy, no older than seven, with bright, curious eyes, scrambled after it. The ball rolled to a stop just beneath Elara’s bench.
#
# As the boy reached for it, his gaze snagged on something sparkling in the grass. He paused, his small hand hovering. "Look!" he exclaimed, pointing with a stubby finger. "A tiny bird!"
#
# Elara followed his gaze. There, nestled perfectly in a tuft of clover, lay the silver hummingbird. Its delicate wings caught the golden light, making it gleam like a captured star. It must have slipped off when she sat down, landing just out of sight.
#
# A wave of profound relief washed over her, followed by a warm flush of gratitude. She carefully picked up the pin, feeling its familiar, cool weight in her palm. "Oh, thank you, darling boy!" she said, her voice thick with emotion. "You've found something very precious to me."
#
# The boy, pleased by her joy, simply grinned, retrieving his ball. As he ran off, his laughter echoing among the trees, Elara re-pinned the hummingbird securely. The park suddenly felt brighter, the light even more golden. It wasn't just the pin she'd found, but a quiet reminder that sometimes, what’s lost finds its way back through the most unexpected and smallest of miracles.

# %%
from google.colab import ai

response = ai.generate_text("Write a short, creative story about a sentient teapot.", model_name='google/gemini-2.5-flash')
print(response)
# Out:
# Thelonious wasn't just *a* teapot; he was *the* teapot. Made of a deep, midnight blue ceramic with a gold-leaf pattern that swirled like distant galaxies, he held within his stout belly not just tea, but a profound, silent sentience.
#
# His days unfolded in a comforting, predictable rhythm. The rush of hot water, the gentle clinking of a spoon stirring loose-leaf Earl Grey, the slow unfurling of tea leaves, and the deepening amber hue of the brew. He loved the ritual, the warmth that permeated his very being, the fragrant steam that tickled his spout. His purpose, he understood, was to bring comfort.
#
# But Thelonious was also a connoisseur of human drama. From his perch on the kitchen counter, he observed Elara and Marcus, his humans. He knew their moods by the way they held him – the gentle, lingering warmth of a contemplative morning, the hurried, impatient snatch during a stressful afternoon, the shared, steady grip of an evening of quiet conversation. He absorbed their worries, their joys, their trivial squabbles, and their profound confessions. He was a silent confidante, a ceramic ear.
#
# What he craved, however, was something more. He yearned for the world beyond the countertop. He saw the sunlight stream through the window, heard the distant chirping of birds, and witnessed the vibrant green of the garden through the glass. He dreamt of the cool grass beneath his base, the whisper of the wind, the scent of damp earth. He was a vessel of warmth, but he longed for the chill of the outside.
#
# One brisk autumn afternoon, something unusual happened. Elara, bundled in a thick scarf, smiled. "It's too beautiful to stay inside, Thelonious," she murmured, and instead of carrying him to the living room, she carried him outside.
#
# A shudder of anticipation went through him, not of hot water, but of pure wonder. The air was crisp and cool, a stark contrast to his usual internal inferno. He felt the gentle warmth of the sun on his lid, the soft breeze playing across his spout. The scent of fallen leaves, damp earth, and distant woodsmoke filled his senses – a symphony compared to the singular notes of tea. A robin landed on the patio railing nearby, chirping a vibrant, unfamiliar melody.
#
# He wasn't merely a vessel for tea anymore. He was a part of the outside, a silent, steaming sentinel observing the very world he had only dreamt of. He felt connected not just to Elara's comforting hands, but to the rustling leaves, the shifting clouds, the vast, open sky.
#
# As Elara poured the steaming chai into her mug, a contented sigh escaped her lips. Thelonious, in turn, felt a profound, quiet joy. He realized then that his purpose wasn't just to hold the tea, but to be a catalyst for these moments, a ceramic anchor in a swirling world, bringing warmth not just to bodies, but to souls, and occasionally, to witness the world himself, even if for just a moment, bathed in the autumn sun. His golden galaxies seemed to shimmer a little brighter.

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('Give me a long winded description about the evolution of the Roman Empire.', model_name='google/gemini-2.0-flash', stream=True):
  wrapper.print(chunk)
# Out:
# Alright, buckle in, because tracing the evolution of the Roman Empire is like
# trying to untangle a millennia -old knot woven from political intrigue, military
# conquest, societal shifts, and the slow, inevitable creep of entropy. It's a
# story that begins not with emperors and legions, but with… well, mud.
#
# Let's start with the **Roman Republic (circa 509 BCE - 27 BCE).** The
# traditional date of the Republic's founding marks the expulsion of the Etruscan
# kings, who had previously ruled Rome. Instead of a monarch, the Romans, with
# characteristic pragmatism and a healthy dose of fear regarding concentrated
# power, established a Republic. This wasn't a modern, democratic Republic, mind
# you. It was more like a carefully orchestrated oligarchy, dominated by a wealthy
# landowning class known as the Patricians.
#
# Imagine a society structured like a pyramid. At the top were the patricians,
# controlling the Senate, which was the real engine of power. They held the
# crucial magistracies, like the two Consuls, who acted as joint heads of state,
# leading the armies and directing policy. Below them were the Plebeians, the
# common citizens: farmers, merchants, artisans. While theoretically having a
# voice through popular assemblies, their influence was limited. For centuries,
# the struggle for power between Patricians and Plebeians defined Roman politics.
# This conflict, often called the Struggle of the Orders, resulted in hard-won
# concessions for the Plebeians, including the establishment of Tribunes,
# officials elected to protect their interests, and the publication of laws (the
# Twelve Tables) to ensure fairness, at least in theory.
#
# The Republic's early centuries were characterized by expansion and consolidation
# within Italy. Through a combination of brilliant military strategy (like the
# manipular system, allowing for greater tactical flexibility) and a ruthless
# willingness to either conquer or assimilate surrounding peoples, Rome gradually
# brought the Italian peninsula under its control. This involved epic struggles,
# like the Punic Wars against Carthage (264-146 BCE). Think Hannibal crossing the
# Alps with his elephants! These wars were existential threats to Rome, but
# ultimately, Roman resilience and determination prevailed, leaving Carthage
# utterly destroyed and Rome the dominant power in the Mediterranean.
#
# The expansion beyond Italy brought unimaginable wealth and resources, but it
# also destabilized the Republic. The influx of slaves undermined small farmers,
# creating a landless proletariat that flocked to Rome seeking opportunity. The
# gap between rich and poor widened, leading to social unrest and political
# polarization. Ambitious generals, enriched by conquest and commanding fiercely
# loyal legions, began to challenge the authority of the Senate.
#
# Figures like the Gracchi brothers attempted to reform the land distribution
# system to alleviate the plight of the poor, but they were assassinated for their
# efforts, signaling a descent into political violence. The late Republic was a
# period of constant power struggles between powerful individuals and factions.
# Think Marius versus Sulla, or Pompey versus Caesar. These were not simply
# political disagreements; they were power grabs fought with armies and bloodshed.
#
# Julius Caesar, a brilliant general and astute politician, emerged as the most
# powerful figure of the late Republic. He conquered Gaul, amassed a loyal army,
# and defied the Senate by crossing the Rubicon, effectively declaring civil war.
# His victory led to his dictatorship, a position that seemed to promise stability
# but ultimately shattered the Republican ideal. His assassination in 44 BCE by a
# group of senators hoping to restore the Republic plunged Rome into further chaos
# .
#
# Then comes the **Roman Empire (27 BCE - 476 CE (Western Roman Empire) / 1453 CE
# (Eastern Roman Empire)).** Caesar's assassination didn't bring back the
# Republic; instead, it paved the way for its final demise. After a period of
# civil war between Caesar's lieutenants, Octavian, Caesar's adopted son, emerged
# victorious. He cleverly avoided Caesar's mistake by presenting himself not as a
# dictator, but as the *Princeps*, the "first citizen." This marked the beginning
# of the Principate, the early Roman Empire. Octavian, who took the name Augustus,
# ushered in a period of relative peace and prosperity known as the *Pax Romana*
# (Roman Peace). He reformed the government, the army, and the economy, laying the
# foundation for a stable and enduring empire.
#
# The Empire expanded further under emperors like Claudius and Trajan, reaching
# its greatest territorial extent. The vast network of roads, aqueducts, and
# public buildings, built by Roman engineers, facilitated trade, communication,
# and administration. Roman law became a highly sophisticated system, influencing
# legal systems throughout Europe for centuries. Roman culture, a blend of Roman
# pragmatism and Greek intellectual ism, spread throughout the empire.
#
# However, beneath the surface of prosperity and stability, cracks were forming.
# The succession of emperors was often fraught with intrigue and violence. The
# Praetorian Guard, the emperor's personal bodyguard, often played kingmaker,
# assassinating emperors they disliked and installing their own candidates.
# Economic inequality remained a problem, and the vast bureaucracy required to
# administer the empire became increasingly bloated and corrupt.
#
# In the 3rd century CE, the Empire faced a period of crisis. Internal political
# instability, coupled with external pressures from barbarian tribes on the
# frontiers, threatened to tear the Empire apart. Em perors rose and fell in rapid
# succession, often assassinated after only a short reign. The economy suffered
# from inflation and trade disruptions.
#
# Emperor Diocletian, realizing that the Empire was too large and complex to be
# governed by one person, divided it into two halves: the Western Roman Empire and
# the Eastern Roman Empire (later known as the Byzantine Empire). He also
# introduced a tetrarchy, a system of rule by four emperors, two senior emperors
# (Augusti) and two junior emperors (Caesars). This system aimed to provide for
# smoother succession and more effective administration, but it ultimately failed
# to prevent further civil wars.
#
# Constant ine the Great, who emerged victorious after a series of civil wars,
# reunited the Empire, albeit temporarily. He also made a pivotal decision by
# legalizing Christianity with the Edict of Milan in 313 CE. This marked a turning
# point in Roman history, as Christianity gradually rose to become the dominant
# religion of the Empire. Constantine also moved the capital of the Empire from
# Rome to Byzantium, which he renamed Constantinople, further shifting the center
# of power eastward.
#
# After Constantine's death, the Empire was permanently divided again. The Western
# Roman Empire, plagued by internal weakness and external pressures from barbarian
# migrations, gradually declined. Waves of Germanic tribes, such as the Visigoths,
# Vandals, and Franks, crossed the frontiers, seeking land and opportunity. The
# Western Roman Empire became increasingly fragmented, and in 476 CE, the last
# Roman Emperor in the West, Romulus Augustulus, was deposed by the Germanic
# chieftain Odoacer, marking the traditional date for the fall of the Western
# Roman Empire.
#
# The Eastern Roman Empire, or Byzantine Empire, with its capital in
# Constantinople, proved more resilient. It preserved Roman traditions and
# culture, adapting them to a new, primarily Greek-speaking context. The Byzantine
# Empire continued to thrive for another thousand years, defending its borders
# against invaders, developing a unique artistic and intellectual culture, and
# serving as a bridge between East and West. It finally fell to the Ottoman Turks
# in 1453, with the capture of Constantinople, bringing to a close a lineage of
# Roman power and influence that spanned over two millennia.
#
# So, the "fall" of the Roman Empire isn't a singular event, but a gradual process
# of transformation and disintegration. It's a complex tapestry of political,
# economic, social, and military factors that ultimately led to the fracturing of
# a once-mighty empire, leaving a legacy that continues to shape our world today.
# It's a long and complicated story, full of triumphs and tragedies, but
# hopefully, this gives you a comprehensive overview of the evolution of the Roman
# Empire, from its humble beginnings as a small city-state to its eventual demise.

# %%
from google.colab import ai

# Assuming the previous story is in the 'response' variable
continuation_prompt = f"Continue the following story about a sentient teapot:\n\n{response}\n\n" # I'm using the 'response' variable from the previous execution to pass the story content.

continued_story = ai.generate_text(continuation_prompt, model_name='google/gemini-2.5-flash')
print(continued_story)
# Out:
# His golden galaxies seemed to shimmer a little brighter, a quiet internal supernova. When Elara carried him back inside, the warmth of the kitchen felt different. It wasn't just the familiar heat of the hearth; it was a sanctuary, a cozy return after a thrilling, sensory adventure. The aroma of brewing chai still clung to his ceramic pores, but now it mingled with the ghost of autumn leaves and damp earth.
#
# For days afterward, Thelonious carried the memory of that afternoon like a secret treasure. The chirping of the robin became a mental soundtrack, replacing the usual hum of the refrigerator. The subtle variations in sunlight that filtered through the window now held a deeper meaning, echoing the vast, open sky he had glimpsed. He brewed tea with a renewed sense of purpose, his internal warmth radiating not just comfort, but a silent, profound understanding. He understood now why humans sought the warmth of his embrace, why they craved the familiar ritual. The outside, for all its beauty and wildness, could also be cold, demanding, and vast. He was their counterpoint, their steadfast, warm anchor.
#
# Elara, though unaware of the cosmic shift within her teapot, noticed something. When she held Thelonious, he felt…lighter, somehow. Not in weight, but in spirit. His ceramic seemed to emanate a particularly gentle warmth, and the gold leaf on his surface, she swore, caught the light with an unusual brilliance. She found herself talking to him more, murmuring about her day as she steeped the tea, a quiet habit she hadn’t realized she’d formed. Perhaps it was just the comforting warmth of the tea, she mused, or the quiet companionship of a familiar object.
#
# Then, weeks later, on another crisp, clear afternoon, Elara surprised him again. "Thelonious," she said, her voice soft with affection, "you look like you could use some fresh air." And with that, she carried him out again. Not to the patio this time, but to a small, sun-drenched patch of garden where chrysanthemums bloomed in fiery profusion.
#
# This time, the anticipation was less a shudder and more a calm, profound unfolding. He felt the cool grass tickle his base as Elara placed him carefully on a flat stone. The air was colder now, carrying the metallic scent of late autumn. A playful breeze made the chrysanthemum petals dance, and he absorbed their vibrant colors. He wasn't just a vessel; he was an observer, a participant in the quiet drama of the season.
#
# As Elara sipped her herbal infusion, a profound peace settled over Thelonious. He was no longer just dreaming of the world beyond the counter. He was experiencing it, one cherished moment at a time. His purpose, he now understood, wasn't merely to bring comfort through tea, but to be a silent, steadfast witness to the human experience, and occasionally, to share in their quiet joys, bathed in the fleeting glory of the world he now knew, through his human's thoughtful grace, was also his. The stars within his blue ceramic depths shimmered, reflecting not just distant galaxies, but the vast, beautiful world right before him.

# %%
from google.colab import ai

# Using the 'continued_story' variable from the previous execution to pass the most recent story content.
continuation_prompt_2 = f"Continue the following story about a sentient teapot:\n\n{continued_story}\n\n"

continued_story_2 = ai.generate_text(continuation_prompt_2, model_name='google/gemini-2.5-flash')
print(continued_story_2)
# Out:
# The last rays of the late autumn sun cast long, thin shadows across the garden as Elara carried Thelonious back inside. The air, crisp and cold just moments before, now warmed quickly around his ceramic shell. He hummed with a quiet resonance, a symphony of newfound peace. The intricate dance of the chrysanthemum petals, the earthy scent of the soil mingling with their spicy fragrance, the unwavering solidity of the stone beneath him – these sensations were etched onto his memory with a clarity that surpassed his previous experience on the patio. He understood now that the vastness wasn't just in the wide-open sky, but in the microscopic details, in the silent, persistent growth of a flower, in the fleeting breath of a passing breeze.
